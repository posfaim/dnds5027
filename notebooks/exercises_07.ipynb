# %% [markdown]
# # Python for everyone -- 07 Dictionaries
#
# ## Exercises

# %% [markdown]
# #### 🔴 Fix the code
#
# Write the code below.

# %%
# define a dictionary containing the price of fruits
fruit_price = {"apple"=1, "banana"=0.5, "peach"=1.75}
fruit_price

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# fruit_price = {"apple":1, "banana":0.5, "peach":1.75} # = -> :
# ```
#
# </p>
# </details>

# %%
penguin_weights = {
    "Emperor": 30.0,
    "King": 13.5,
    "Adelie": 4.5,
    "Chinstrap": 4.0,
    "Gentoo": 5.5,
    "Little Blue": 1.2,
    "Magellanic": 4.8,
    "African": 3.0,
    "Rockhopper": 2.5,
    "Macaroni": 5.5
}

max_weight = 0.
for w in penguin_weights.values:
    if w>max_weight:
        max_weight=w
        
print(max_weight)

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# max_weight = 0.
# for w in penguin_weights.values(): # add ()
#     if w>max_weight:
#         max_weight=w
#
# print(max_weight)
# ```
#
# </p>
# </details>

# %%
# create a dictionary w keys that are bird names and values equal to number of words in the bird name
birds = ["golden-crowned sparrow", "red-winged blackbird", "whippoorwill", "american gray flycatcher"]

num_words = []
for b in birds:
    num_words[bird] = len(bird.split())
num_words

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
#
# num_words = {} # [] -> {}
# for bird in birds: # b -> bird
#     num_words[bird] = len(bird.split())
# num_words
#
# ```
#
# </p>
# </details>

# %% [markdown]
# #### 🔴 Keys
#
# Print out the keys of the following dictionary.

# %%
country_populations = {
    "China": 1405.0,
    "India": 1428.0,
    "United States": 342.0,
    "Indonesia": 282.0,
    "Brazil": 216.0
}

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# for c in country_populations.keys():
#     print(c)
#
# # or
#
# for c in country_populations:
#     print(c)
# ```
#
# </p>
# </details>

# %% [markdown]
# #### 🔴 Total value
#
# Print out the total population of the five countries in the dictionary.
#
# <details><summary><u>Hint.</u></summary>
#
# You need a helper variable that keeps track of the total population during summation.
#
# </details>

# %%
country_populations = {
    "China": 1405.0,
    "India": 1428.0,
    "United States": 342.0,
    "Indonesia": 282.0,
    "Brazil": 216.0
}

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# total = 0.
# for pop in country_populations.values():
#     total += pop
# print(total)
# ```
#
# </p>
# </details>

# %% [markdown]
# #### 🔴 Fraction of population
#
# Create a new dictionary that instead of the population of the countries in millions, but the population in terms of percentage of the world population.
#
# <details><summary><u>Hint.</u></summary>
#
# You need a helper variable that keeps track of the total population during summation.
#
# </details>

# %%
country_populations = {
    "China": 1405.0,
    "India": 1428.0,
    "United States": 342.0,
    "Indonesia": 282.0,
    "Brazil": 216.0,
    "Vatican City": 0.0008,
    "Nauru": 0.012,
    "Tuvalu": 0.011
}

world_pop = 8250.0

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# country_pop_percentage = {}
# for country, pop in country_populations.items():
#     country_pop_percentage[country] = pop/world_pop * 100
# country_pop_percentage
# ```
#
# </p>
# </details>

# %% [markdown]
# #### 🔴 Cutest penguin species
#
# It is well-known that the smaller a penguin, the cuter it is to the human eye.
#
# Write code that prints out the name of the smallest penguin species.
#
# <details><summary><u>Hint.</u></summary>
#
# You can `penguin_weights.items()` to iterate over the key-value pairs.
#
# </details>

# %%
penguin_weights = {
    "Emperor": 30.0,
    "King": 13.5,
    "Adelie": 4.5,
    "Chinstrap": 4.0,
    "Gentoo": 5.5,
    "Little Blue": 1.2,
    "Magellanic": 4.8,
    "African": 3.0,
    "Rockhopper": 2.5,
    "Macaroni": 5.5
}

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
#
# min_weight = 10000
# for name, weight in penguin_weights.items():
#     if min_weight>weight:
#         min_name = name
#         min_weight = weight
# print(min_name)
#
# ```
#
# </p>
# </details>

# %% [markdown]
# #### 🔴 Invert a dictionary
#
# The below Python dictionary `eng_to_hun` is a small English-Hungarian dictionary, i.e., keys are English words and the values are their Hungarian counterparts. Write code that creates a new dictionary called `hun_to_eng`, which does the opposite.
#
# <details><summary><u>Hint.</u></summary>
#
# You can `penguin_weights.items()` to iterate over the key-value pairs.
#
# </details>

# %%
eng_to_hun = {
    "dog":   "kutya",
    "bicycle": "canga",
    "money": "zsoketta",
    "awesome": "nem rossz",
    "hello": "csácsövi-csá-csá"
}

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# hun_to_eng = {}
# for e,h in eng_to_hun.items():
#     hun_to_eng[h]=e
# hun_to_eng
# ```
#
# </p>
# </details>

# %% [markdown]
# #### 🔴 Structured data
#
# `weather` is list of dictionaries which contains weather forcast for the next few days: `weather[0]` is tomorrow, `weather[1]` is the day after tomorrow, and so on.

# %%
weather = [
    {'min_temp_C': 4, 'max_temp_C': 14, 'percip_mm':0},
    {'min_temp_C': 4, 'max_temp_C': 12, 'percip_mm':1.2},
    {'min_temp_C': -1, 'max_temp_C': 11, 'percip_mm':2.2},
    {'min_temp_C': -2, 'max_temp_C': 8, 'percip_mm':0},
    {'min_temp_C': 3, 'max_temp_C': 16, 'percip_mm':0}
]

# %% [markdown]
# Write code that prints out tomorrow's maximum temperature.

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
#
# print(weather[0]['max_temp_C'])
#
# ```
#
# </p>
# </details>

# %% [markdown]
# Count the number of days when it rains.

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# count = 0
# for daily_forecast in weather:
#     if daily_forecast['percip_mm']>0:
#         count += 1
# print(f"The number of rainy days is {count}.")
#
# ```
#
# </p>
# </details>

# %% [markdown]
# What is the average minimum temperature in the next three days?
#
#
# <details><summary><u>Hint.</u></summary>
#
# The next three days is the first three entries in the `weather` list. Use slicing!
# </details>

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
#
# total = 0
# for daily_forecast in weather[:3]:
#     total += daily_forecast['min_temp_C']
#
# average = total/3
#
# print(f"The average minimum temperature is {average:.2f}.")
# ```
#
# </p>
# </details>

# %% [markdown]
# ## Homework
#
# 🔴 Dictionary of dictionaries
#
# The dictionary below contains some information about different sports. Write code to answer the following questions:
# * What do you call it when you score in rugby?
# * Which sports are included in the dictionary?
# * Which game requires the least players?
#
# Hint: the last question is similar to the exercises of finding the cutest penguin.

# %%
ball_sports = {
    "soccer": {
        "players_per_team": 11,
        "game_length_minutes": 90,
        "score_name": "goal"
    },
    "basketball": {
        "players_per_team": 5,
        "game_length_minutes": 48,
        "score_name": "basket"
    },
    "baseball": {
        "players_per_team": 9,
        "game_length_minutes": 180,
        "score_name": "run"
    },
    "volleyball": {
        "players_per_team": 6,
        "game_length_minutes": 90,
        "score_name": "point"
    },
    "rugby": {
        "players_per_team": 15,
        "game_length_minutes": 80,
        "score_name": "try"
    }
}
